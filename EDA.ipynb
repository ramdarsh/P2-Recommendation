# %% [markdown]
# <a href="https://colab.research.google.com/github/ramdarsh/P2-Recommendation/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''ADD SCRAPING SCRIPT HERE'''

# %%
data = pd.read_csv('movieMetadata.csv')
data.head()
# Out:
#                            Movie Title  \
# 0             The Shawshank Redemption
# 1                        The Godfather
# 2  Ramayana: The Legend of Prince Rama
# 3                       Hababam Sinifi
# 4                      The Dark Knight
#
#                                          Description  \
# 0  Over the course of several years, two convicts...
# 1  Don Vito Corleone, head of a mafia family, dec...
# 2  An anime adaptation of the Hindu epic the Rama...
# 3  Lazy, uneducated students share a very close b...
# 4  When the menace known as the Joker wreaks havo...
#
#                         Genre  Rating Metascore Gross_Income      Votes  \
# 0                       Drama     9.3        82      $28.34M  2,806,728
# 1                 Crime,Drama     9.2       100     $134.97M  1,955,879
# 2  Animation,Action,Adventure     9.2      $$$$         none     13,028
# 3                Comedy,Drama     9.2      $$$$         none     42,246
# ...

# %%
data.tail()
# Out:
#                                  Movie Title  \
# 10095                           Bastille Day
# 10096                       American Wedding
# 10097                       A View to a Kill
# 10098  Hotel Transylvania 3: Summer Vacation
# 10099                                  Ted 2
#
#                                              Description  \
# 10095  A young pickpocket and an unruly CIA agent tea...
# 10096  It's the wedding of Jim and Michelle and the g...
# 10097  The recovery of a microchip off the body of a ...
# 10098  Count Dracula and company participate in a cru...
# 10099  Newlywed couple Ted and Tami-Lynn want to have...
#
#                             Genre  Rating Metascore Gross_Income    Votes  \
# 10095          Action,Crime,Drama     6.3        48       $0.04M   49,508
# 10096                      Comedy     6.3        43     $104.57M  213,811
# 10097   Action,Adventure,Thriller     6.3        40      $50.33M  102,530
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie Title   10100 non-null  object
#  1   Description   10100 non-null  object
#  2   Genre         10100 non-null  object
#  3   Rating        10100 non-null  float64
#  4   Metascore     10100 non-null  object
#  5   Gross_Income  10100 non-null  object
#  6   Votes         10100 non-null  object
#  7   Runtime       10100 non-null  int64
#  8   Certificate   10100 non-null  object
#  9   Year          10100 non-null  object
#  10  Director      10100 non-null  object
#  11  Stars         10091 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 947.0+ KB

# %%
data['Metascore'] = pd.to_numeric(data['Metascore'], errors='coerce')

data['Votes'] = data['Votes'].str.replace(',', '').astype('int64')

# %%
data.shape
# Out:
# (10100, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie Title   10100 non-null  object
#  1   Description   10100 non-null  object
#  2   Genre         10100 non-null  object
#  3   Rating        10100 non-null  float64
#  4   Metascore     8005 non-null   float64
#  5   Gross_Income  10100 non-null  object
#  6   Votes         10100 non-null  int64
#  7   Runtime       10100 non-null  int64
#  8   Certificate   10100 non-null  object
#  9   Year          10100 non-null  object
#  10  Director      10100 non-null  object
#  11  Stars         10091 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 947.0+ KB

# %%
cols = data.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
data['Metascore'] = data['Metascore'].fillna(0)

# %%
import seaborn as sns
cols = data.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie Title   10100 non-null  object
#  1   Description   10100 non-null  object
#  2   Genre         10100 non-null  object
#  3   Rating        10100 non-null  float64
#  4   Metascore     10100 non-null  float64
#  5   Gross_Income  10100 non-null  object
#  6   Votes         10100 non-null  int64
#  7   Runtime       10100 non-null  int64
#  8   Certificate   10100 non-null  object
#  9   Year          10100 non-null  object
#  10  Director      10100 non-null  object
#  11  Stars         10091 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 947.0+ KB

# %%
data.describe()
# Out:
#              Rating     Metascore         Votes       Runtime
# count  10100.000000  10100.000000  1.010000e+04  10100.000000
# mean       6.765693     47.145842  1.025622e+05    111.292871
# std        0.849625     28.640034  2.192917e+05     22.687211
# min        4.900000      0.000000  1.000000e+04     45.000000
# 25%        6.200000     31.000000  1.684025e+04     96.000000
# 50%        6.800000     53.000000  3.429500e+04    107.000000
# 75%        7.400000     68.000000  9.327775e+04    121.000000
# max        9.300000    100.000000  2.806728e+06    439.000000

# %%
data['Metascore'].unique()
# Out:
# array([ 82., 100.,   0.,  84.,  95.,  94.,  97.,  90.,  67.,  92.,  74.,
#         87.,  86.,  73.,  65.,  91.,  61.,  79.,  96.,  75.,  59.,  89.,
#         98.,  85.,  88.,  81.,  66.,  64.,  77.,  62.,  57.,  80.,  99.,
#         69.,  78.,  83.,  68.,  76.,  71.,  70.,  58.,  60.,  63.,  93.,
#         55.,  72.,  47.,  33.,  49.,  54.,  50.,  46.,  36.,  51.,  53.,
#         48.,  56.,  40.,  44.,  52.,  45.,  30.,  28.,  37.,  41.,  43.,
#         31.,  35.,  34.,  38.,  42.,  29.,  32.,  27.,  25.,  39.,  24.,
#         22.,  21.,  23.,  18.,  19.,  16.,  13.,  26.,  14.,  10.,  17.,
#         11.,  20.,  12.,  15.,   9.,   7.])

# %%
'''Distribution of Metascore'''

plt.figure(figsize=(5,4))
Mtmean = data['Metascore'].mean()
sns.distplot(data['Metascore'],color='g', label = f'Average Metascore: {Mtmean}')
plt.axvline(x=Mtmean,linestyle='-.')
plt.legend()
plt.show()

# %%
'''Distribution of Runtime'''

plt.figure(figsize=(5,4))
sns.distplot(data['Runtime'],)
Rtmean = data['Runtime'].mean()
plt.axvline(x=data['Runtime'].mean(),linestyle='-.',label= f'Average runtime: {Rtmean}')
plt.legend()

plt.show()

# %%
'''Distribution of Votes'''

plt.figure(figsize=(5,4))
sns.distplot(data['Votes'],)
plt.show()

# %%
data.corr()
# Out:
#             Rating  Metascore     Votes   Runtime
# Rating     1.00000   0.194440  0.339290  0.361090
# Metascore  0.19444   1.000000  0.275221 -0.003457
# Votes      0.33929   0.275221  1.000000  0.233653
# Runtime    0.36109  -0.003457  0.233653  1.000000

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()
# Create a heatmap to visualize the correlations
plt.figure(figsize=(7, 3))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df = data.dropna(subset=['Rating', 'Genre'])
bins = range(1, 12)

# Plot histogram
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='Rating', bins=bins, multiple='stack', palette='viridis')
plt.title('Histogram of Rating ')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
data.Metascore.max()
# Out:
# 100.0

# %%
'''CROSS CHECK'''

# %%
df = data.dropna(subset=['Metascore', 'Genre'])

# Create bins for the histogram with a range from 1 to 10 (inclusive)
bins = range(1, 12)

# Plot histogram
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='Metascore', bins=bins, color='purple')
plt.title('Histogram of Metascore')
plt.xlabel('Metascore')
plt.ylabel('Count')
plt.show()

# %%
# Calculate average Metascore score for each genre
avg_metacore = df.groupby('Genre')['Metascore'].mean().reset_index()

# Get the top 10 genres by average Metascore
top_10_genres = avg_metacore.nlargest(25, 'Metascore')

# Plotting a barplot for the top 10 genres
plt.barh(top_10_genres['Genre'], top_10_genres['Metascore'],color = 'g')
plt.xlabel('Average Metascore Score')
plt.ylabel('Genre')
plt.title('Top 10 Genres by Average Metascore')
plt.show()

# %%
plt.scatter(data['Rating'], data['Metascore'], color='skyblue')
plt.xlabel('Rating')
plt.ylabel('Metascore')
plt.title('Relationship between Rating and Metascore')
plt.show()

# %%
# Visualize how the average rating or Metascore has changed over the years.
# Are newer movies generally better

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Drop rows with NaN values in 'Year', 'Rating', and 'Metascore' columns
df = data.dropna(subset=['Year', 'Metascore'])

# Convert 'Year' to numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Group by 'Year' and calculate the average rating and Metascore for each year
avg_scores_by_year = df.groupby('Year')[['Metascore']].mean()

# Line plot for Average Rating and Metascore over the years
plt.figure(figsize=(12, 4))
sns.lineplot(data=avg_scores_by_year, markers=True, palette="tab10")
plt.title('Average Metascore Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Score')
plt.legend(['Metascore'])
plt.show()

# %%
# Drop rows with NaN values in 'Year', 'Rating', and 'Metascore' columns
df = data.dropna(subset=['Year', 'Rating'])

# Convert 'Year' to numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Group by 'Year' and calculate the average rating and Metascore for each year
avg_scores_by_year = df.groupby('Year')[['Rating']].mean()

# Line plot for Average Rating and Metascore over the years
plt.figure(figsize=(10,4))
sns.lineplot(data=avg_scores_by_year, markers=True, palette="tab10")
plt.title('Average Rating Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Score')
plt.legend(['Rating'])
plt.show()

# %%
df = data.dropna(subset=['Certificate'])

# Count the occurrences of each certificate type
certificate_counts = df['Certificate'].value_counts()

# Bar plot for distribution of movies across certificate types
plt.figure(figsize=(10, 4))
sns.barplot(x=certificate_counts.index, y=certificate_counts.values, palette="Set3")
plt.title('Distribution of Movies Across Certificate Types')
plt.xlabel('Certificate Type')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Calculate average rating for each certificate
avg_ratings = df.groupby('Certificate')['Rating'].mean().reset_index()

# Plotting a barplot
plt.subplots(figsize=(4,7))
plt.barh(avg_ratings['Certificate'], avg_ratings['Rating'], color='plum')
plt.xlabel('Average Rating')
plt.ylabel('Certificate')
plt.title('Average Rating by Certificate')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = data.dropna(subset=['Gross_Income', 'Rating'])

# Clean 'Gross_Income' column by removing non-numeric characters
df['Gross_Income'] = df['Gross_Income'].replace('[^\d.]', '', regex=True)

# Convert 'Gross_Income' to numeric
df['Gross_Income'] = pd.to_numeric(df['Gross_Income'], errors='coerce')

# Scatter plot for Gross Income vs. User Ratings
plt.figure(figsize=(10, 4))
sns.scatterplot(x='Gross_Income', y='Rating', data=df, color='skyblue', alpha=0.7)
plt.title('Gross Income vs. User Ratings')
plt.xlabel('Gross Income')
plt.ylabel('User Rating')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['Gross_Income'].corr(df['Rating'])
print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: 0.13975085958314692

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
sns.scatterplot(x='Rating', y='Votes', data=data, color='lightcoral', alpha=0.7)
plt.title('Rating vs. Votes')
plt.xlabel('Rating')
plt.ylabel('Votes')
plt.show()

# %%
df = data.dropna(subset=['Metascore', 'Votes'])

# Clean 'Metascore' by removing non-numeric characters
df['Metascore'] = df['Metascore'].replace('[^\d.]', '', regex=True)

# Convert 'Metascore' to numeric
df['Metascore'] = pd.to_numeric(df['Metascore'], errors='coerce')

# Scatter plot for Metascore vs. Votes
sns.scatterplot(x='Metascore', y='Votes', data=df, color='green', alpha=0.7)
plt.title('Metascore vs. Votes')
plt.xlabel('Metascore')
plt.ylabel('Votes')
plt.show()

# %%
sns.scatterplot(x='Runtime', y='Votes', data=data, color='red', alpha=0.7)
plt.title('Runtime vs. Votes')
plt.xlabel('Runtime')
plt.ylabel('Votes')
plt.show()

# %%
df = data.dropna(subset=['Rating', 'Stars'])# drop null values

# Select the top 100 actors based on the number of movies they've starred in
top_actors = df['Stars'].value_counts().head(20).index

# Filter the DataFrame to include only movies with the top actors
df_top_actors = df[df['Stars'].isin(top_actors)]

# Create bins for the histogram with a range from 1 to 10 (inclusive)
bins = range(1, 12)

# Plot bar plot
plt.figure(figsize=(4,5))
sns.barplot(data=df_top_actors, x='Rating', y='Stars', ci=None, palette='viridis')
plt.title('Average Rating by Top 100 Actors')
plt.xlabel('Rating')
plt.ylabel('Stars')
plt.show()

# %%
certificate_counts = data['Certificate'].value_counts()
# Create a bar plot to visualize the distribution of movies by certificate
plt.figure(figsize=(28, 5))
certificate_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Certificate')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movies by Certificate')
plt.xticks(rotation=0)  # Keep certificate labels horizontal for better readability

plt.show()

# %%
# Calculate average rating for each certificate
avg_ratings = df.groupby('Certificate')['Votes'].mean().reset_index()

# Plotting a barplot
plt.subplots(figsize=(4,6))
plt.barh(avg_ratings['Certificate'], avg_ratings['Votes'], color='plum')
plt.xlabel('Average Votes')
plt.ylabel('Certificate')
plt.title('Average Votes by Certificate')
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

popular = df[['Movie Title','Rating']]
popular=popular.sort_values(by='Rating',ascending=False).reset_index().head(99)
popular.drop(columns='index',axis=0,inplace=True)

fig = px.scatter( popular, x='Movie Title',y='Rating', color ='Rating',size='Rating',width=950, height=650)
fig.update_layout(
    title="Most Rated  movies of all time",
    xaxis_title="Movies",
    yaxis_title="Rating",
    legend_title="Popularity",
    font=dict(
        size=14
    )
)
fig.layout.template = 'plotly'
fig.show()
# Out:
# <div>                            <div id="58125945-e4c8-409a-ae8e-73f1f08d81af" class="plotly-graph-div" style="height:650px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58125945-e4c8-409a-ae8e-73f1f08d81af")) {                    Plotly.newPlot(                        "58125945-e4c8-409a-ae8e-73f1f08d81af",                        [{"hovertemplate":"Movie Title=%{x}<br>Rating=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[9.3,9.3,9.3,9.3,9.2,9.2,9.2,9.2,9.2,9.2,9.2,9.2,9.2,9.2,9.2,9.2,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.9,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8.8,8
# ...

# %%
yearly_gross_income = data.groupby('year')['Gross_Income'].sum()

# Create a line plot to show changes in gross income over the years
plt.figure(figsize=(10, 6))
plt.plot(yearly_gross_income.index, yearly_gross_income, marker='o', color='skyblue')
plt.xlabel('year')
plt.ylabel('Total Gross Income')
plt.title('Gross Income Over the Years (Line Plot)')

plt.bar(yearly_gross_income.index, yearly_gross_income, color='skyblue')

plt.grid(True)
plt.show()

# %% [markdown]
# ![p2year.png](attachment:p2year.png)

# %%
director_counts = data['Director'].value_counts()

# Sort the directors by the number of movies
director_counts = director_counts.sort_values(ascending=False)

# Choose how many top directors you want to visualize (e.g., top 5)
top_directors = director_counts.head(10)

# Create a bar plot to visualize the top directors
plt.figure(figsize=(10, 3))
top_directors.plot(kind='bar', color='skyblue')
plt.xlabel('Director')
plt.ylabel('Number of Movies')
plt.title('Top Directors with Most Movies')
plt.xticks(rotation=45)  # Rotate the director labels for better readability

plt.show()

# %%
yearly_counts = data['year'].value_counts().sort_index()

# Create a bar chart to visualize the distribution of movies by year
plt.figure(figsize=(18, 5))
yearly_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movies Over the Years')
plt.xticks(rotation=90)  # Rotate the year labels for better readability

plt.show()

# %% [markdown]
# Reduction in released movies during and after Covid19

# %%
# Count the number of movies in each genre category
genre_counts = data['Genre'].value_counts()
# Select the top 10 genres
top_10_genres = genre_counts.head(10)

# pie chart to show the distribution of the top 20 genres
plt.figure(figsize=(5,5))
plt.pie(top_10_genres, labels=top_10_genres.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Top 10 Genres')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()
